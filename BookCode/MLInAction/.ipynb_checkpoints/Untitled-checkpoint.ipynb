# %%
# %pylab
# Out:
# Using matplotlib backend: Qt5Agg
# Populating the interactive namespace from numpy and matplotlib

# %%
# %matplotlib inline

# %%
import matplotlib
import numpy

# %%
x = linspace(0, 2 * pi , 50 )
plot(sin(x))

# %%
plot(x, sin(x))

# %%
plot(x, sin(x), x, sin(2 * x))
# Out:
# [<matplotlib.lines.Line2D at 0x7fed8c12b208>,
#  <matplotlib.lines.Line2D at 0x7fed8c12bb70>]

# %%
plot(x, sin(x) , 'r--^')

# %%
plot(x, sin(x), 'b-o', 
    x, sin(2 * x), 'r--')
# Out:
# [<matplotlib.lines.Line2D at 0x7fed84c8e358>,
#  <matplotlib.lines.Line2D at 0x7fed84c8e4e0>]

# %%
plot(x, sin(x), 'bo')

# %%
scatter(x, sin(x))

# %%
x = rand(200)
y = rand(200)
size = rand(200) * 30 
color = rand(200)
scatter(x, y, size, color)
colorbar()

# %%
t = linspace(0, 2*pi, 50)
x = sin(t)
y = cos(t)
figure()
plot(x)
figure()
plot(y)

# %%
subplot(1, 2, 1)
plot(x)
subplot(1, 2, 2)
plot(y)

# %%
plot(x)
plot(y)
hold(False)
# Out:
# /home/shiyanlou/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/shiyanlou/anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py:917: UserWarning: axes.hold is deprecated. Please remove it from your matplotlibrc and/or style files.
#   warnings.warn(self.msg_depr_set % key)
# /home/shiyanlou/anaconda3/lib/python3.6/site-packages/matplotlib/rcsetup.py:152: UserWarning: axes.hold is deprecated, will be removed in 3.0
#   warnings.warn("axes.hold is deprecated, will be removed in 3.0")

# %%
plot(x, sin(x))

# %%
clf()

# %%
from scipy.misc import face

# %%
img = face()

# %%
img
# Out:
# array([[[121, 112, 131],
#         [138, 129, 148],
#         [153, 144, 165],
#         ...,
#         [119, 126,  74],
#         [131, 136,  82],
#         [139, 144,  90]],
#
#        [[ 89,  82, 100],
#         [110, 103, 121],
#         [130, 122, 143],
#         ...,
#         [118, 125,  71],
#         [134, 141,  87],
#         [146, 153,  99]],
#
#        [[ 73,  66,  84],
#         [ 94,  87, 105],
#         [115, 108, 126],
#         ...,
#         [117, 126,  71],
#         [133, 142,  87],
#         [144, 153,  98]],
#
#        ...,
#        [[ 87, 106,  76],
#         [ 94, 110,  81],
#         [107, 124,  92],
#         ...,
#         [120, 158,  97],
#         [119, 157,  96],
#         [119, 158,  95]],
#
#        [[ 85, 101,  72],
#         [ 95, 111,  82],
#         [112, 127,  96],
#         ...,
#         [121, 157,  96],
#         [120, 156,  94],
#         [120, 156,  94]],
#
#        [[ 85, 101,  74],
#         [ 97, 113,  84],
#         [111, 126,  97],
#         ...,
#         [120, 156,  95],
#         [119, 155,  93],
#         [118, 154,  92]]], dtype=uint8)

# %%
imshow(img, 
      extent = [-25, 25, -25, 25], 
      cmap = cm.bone)

# %%
imshow(img, cmap=cm.RdGy_r)

# %%
from numpy import *

# %%
lst = [0, 1, 2, 3]
a = array(lst)

# %%
a.fill(-4.8)
a
# Out:
# array([-4, -4, -4, -4])

# %%
od = array([21000, 211180, 21240, 22100, 22100, 22400])

# %%
dist = od[1:] -od[:-1] #

# %%
dist
# Out:
# array([ 190180, -189940,     860,       0,     300])

# %%
'''
int compute_sum(int *arr, int N) {

    int sum = 0;
    int i ;
    for (i = 0 ; i < N ; i++){
    
        sum += arr[i];
    }

}


'''
# Out:
# '\nint compute_sum(int *arr, int N) {\n\n    int sum = 0;\n    int i ;\n    for (i = 0 ; i < N ; i++){\n    \n        sum += arr[i];\n    }\n\n}\n\n\n'

# %%
a = array([[0, 1, 2, 3], 
           [10, 11, 12, 13]])

# %%
a.shape
# Out:
# (2, 4)

# %%
a.ndim
# Out:
# 2
