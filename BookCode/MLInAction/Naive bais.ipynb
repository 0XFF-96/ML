# %%
#4-5 From ML in action

# %%
def loadDataSet():
    '''
    : return postingList , classVec 
    '''
    
    postingList = [['my', 'dog', 'has', 'flea', 'problems', 'help', 'please'], #[0,0,1,1,1......]
                   ['maybe', 'not', 'take', 'him', 'to', 'dog', 'park', 'stupid'],
                   ['my', 'dalmation', 'is', 'so', 'cute', 'I', 'love', 'him'],
                   ['stop', 'posting', 'stupid', 'worthless', 'garbage'],
                   ['mr', 'licks', 'ate', 'my', 'steak', 'how', 'to', 'stop', 'him'],
                   ['quit', 'buying', 'worthless', 'dog', 'food', 'stupid']]
        
    classVec = [0, 1,  0, 1, 0 , 1]  # 1 is abusive, 0 not 
    
    return postingList, classVec

# %%
def createVocabList(dataSet):
    
    '''
    :param dataSet:
    : return 
    
    
    '''
    
    vocabSet = set([])  # create empty set 
    
    for document in dataSet:
        vocabSet = vocabSet | set(document)   # union of teh two sets 
        
    return list(vocabSet)

# %%
def setOfWords2Vec(vocabList, inputSet):
    
    '''
    : Parm vocabList
    : param inputSet:
    : return 
    
    '''
    
    returnVec = [0] * len(vocabList)  #[0, 0, .....]
    
    for word in inputSet:
        if word in vocabList:
            returnVec[vocabList.index(word)] = 1
            
        else:
            print ('the word %s is not in my Vocabulary!' % word)
            
    return returnVec

# %%
listOPosts, listClasses = loadDataSet()

# %%
myVocabList = createVocabList(listOPosts)

# %%
myVocabList.index('help')  # return the index of the word
# Out:
# 3

# %%
def _trainNB0(trainMatrix, trainCategory):
    
    '''
    : param trainMatrix: [[1, 0, 111...], [], []]
    : param trianCategory : [0, 1, 12, 3, ..]
    : return :
    
    '''
    
    numTrainDocs = len(trainMatrix)
    numWords = len(trainMatrix[0])
    
    pAbsive = sum(trainCategory) / float(numTrainDocs)
    
    p0Num = zeros(numWords)  # [0, 0, 0, ...]
    p1Num = zeros(numWords)  #[0, 0, 0, ...]
    
    p0Denom = 0.0
    p1Denom = 0.0
    
    for i in range(numTrainDocs):
        
        if trainCategory[i] == 1:
            p1Num += trainMatrix[i]
            p1Denom += sum(trainMatrix[i])
            
        else:
            p0Num += trainMatrix[i]
            p0Denom += sum(trianMatrix[i])
            
    p1Vect = p1Num / p1Denom  #[p[]]
    p0Vect = p0Num / p0Denom 
    
    return p0Vect, p1Vect, pAbusive

# %%
def trainNBO(trainMatrix, tarainCategory):
    '''
    : param trainMatrix:
    : param trainCategory:
    : return 
    
    '''
    numTrainDocs = len(trainMatrix)
    numWords = len(trainMatrix[0])
    pAbusive = sum(trainCategory) / float(numTrainDocs)
    
    
    p0Num = ones(numWords)
    p1Num = ones(numWords)
    
    p0Denom = 2.0
    p1Denom = 2.0
    
    for i in range(numTrainDocs):
        if trainCategory[i] == 1:
            p1Num += trainMatrix[i]
            p1Denom += sum(trainMatrix[i])
            
        else:
            p0Num += trainMatrix[i]
            p0Denom += sum(trainMatrix[i])
            
    p1Vect = log(p1Num / p0Denom)
    p0Vect = log(p0Num/ p0Denom )
    
    return p0Vect, p1Vect, pAbusive

# %%
def classifyNB(vec2Classify, p0Vec, p1Vec, pClass1):
    '''
    
    # Algorithm:
        multi: 
        add:
    
    :param vec2Classify:
    :param p0Vec:
    :param p1Vec:
    :param pClass1:
    : return 1 or 0 
    
    '''
    p1 = sum(vec2Classify * p1Vec ) + log(pClass1) # P(w | c1)
    p0 = sum(vec2Classify * p0Vec ) + log(1.0 - pClass1 ) # p(w | c0 ) * p(c0)
    
    if p1 > p0:
        return 1
    else:
        return 0

# %%
def testingNb():
    '''
    1.testing dataset 
    2.word set 
    3.compute 
    '''
    import numpy as np
    trainMat = []
    
    for postinDoc in listOPosts:
        # return m * len(myVocabList)
        trainMat.append(setOfWords2Vec(myVocabList, postinDoc))
        
    p0V, p1V, pAb = trainNBO(np.array(trainMat), np.array(listClasses)) 
    
    testEntry = ['love', 'my', 'dalmation']
    
    thisDoc = array(setOfWords2Vec(myVocabList, testEntry))
    
    print (testEntry , 'classified as : ', classifyNB(thisDoc, p0V, p1V, pAb))

# %%
# !conda list
# Out:
# # packages in environment at /home/shiyanlou/anaconda3:
# #
# _license                  1.1                      py36_1
# alabaster                 0.7.10                   py36_0
# anaconda                  4.4.0               np112py36_0
# anaconda-client           1.6.3                    py36_0
# anaconda-navigator        1.6.2                    py36_0
# anaconda-project          0.6.0                    py36_0
# asn1crypto                0.22.0                   py36_0
# astroid                   1.4.9                    py36_0
# astropy                   1.3.2               np112py36_0
# babel                     2.4.0                    py36_0
# backports                 1.0                      py36_0
# beautifulsoup4            4.6.0                    py36_0
# bitarray                  0.8.1                    py36_0
# blaze                     0.10.1                   py36_0
# bleach                    1.5.0                    py36_0
# ...
